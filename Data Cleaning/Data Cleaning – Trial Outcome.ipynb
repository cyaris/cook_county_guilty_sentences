# %% [raw]
# # schema used to create table in postgres database within AWS.
#
# CREATE TABLE IF NOT EXISTS cook_county_sentencing (
# case_ID varchar(12) NOT NULL,
# case_participant_ID varchar(13) NOT NULL,
# charge_ID varchar(13) NOT NULL,
# charge_version_ID varchar(12) NOT NULL,
# primary_charge text DEFAULT NULL,
# offense_title text DEFAULT NULL,
# chapter text DEFAULT NULL,
# act text DEFAULT NULL,
# section text DEFAULT NULL,
# class text DEFAULT NULL,
# aoic text DEFAULT NULL,
# dispo_date timestamp DEFAULT NULL,
# sentence_phase text DEFAULT NULL,
# sentence_date timestamp DEFAULT NULL,
# sentence_judge text DEFAULT NULL,
# sentence_type text DEFAULT NULL,
# commitment_type text DEFAULT NULL,
# commitment_term text DEFAULT NULL,
# commitment_unit text DEFAULT NULL,
# charge_disposition text DEFAULT NULL,
# charge_disposition_reason text DEFAULT NULL,
# court_name text DEFAULT NULL,
# court_facility text DEFAULT NULL,
# case_length_dats int DEFAULT NULL,
# age_at_incident int DEFAULT NULL,
# gender text DEFAULT NULL,
# race text DEFAULT NULL,
# offense_type text DEFAULT NULL,
# incident_begin_date timestamp DEFAULT NULL,
# incident_end_date timestamp DEFAULT NULL,
# arrest_date timestamp DEFAULT NULL,
# law_enforcement_agency text DEFAULT NULL,
# unit text DEFAULT NULL,
# incident_city text DEFAULT NULL,
# received_date timestamp DEFAULT NULL,
# arraigment_date timestamp DEFAULT NULL,
# current_sentence text DEFAULT NULL
# );
#
# COPY cook_county_sentencing FROM '/home/charlie/cookcountysentencing.csv' DELIMITER ',' CSV HEADER;

# %%
from copy import deepcopy
from sqlalchemy import create_engine
import math
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_colwidth', 1000)
pd.set_option('display.max_columns', None)

# %%
# cnx = create_engine('postgresql://username:password@ip_address:port')

# %% [raw]
# # checking stentence phase counts.
# pd.read_sql_query('''
#
# SELECT sentence_phase, Count(sentence_phase)
# FROM cook_county_sentencing
# GROUP BY sentence_phase
#
# ''', cnx)

# %% [raw]
# # grouped by charge_version_id to see if the same charge ever had different versions.
# pd.read_sql_query('''
#
# SELECT case_id, case_participant_id, charge_id, charge_version_id, sentence_phase, Count(charge_version_id)
# FROM cook_county_sentencing
# GROUP BY charge_version_id, case_id, case_participant_id, charge_id, sentence_phase
# ORDER BY 6 desc
# LIMIT 10
#
# ''', cnx)

# %% [raw]
# # used sql to pull data from aws into local dataframe with appropriate filters applied.
# # case length had to be greater than 0.
# # only pulled data where age_at_incident was recorded, and <=85 because certain outliers seemed unreliable.
# # only pulled data where race and gender were recorded.
# # only included death penalty rows that were consistent across all data fields.
# # only included charge dispositions that were synonymous with plead guilty or found guilty by a jury at trial.
# df = pd.read_sql_query('''
#
# SELECT *
# FROM cook_county_sentencing
# WHERE Cast(case_length_dats AS FLOAT) > 0
# AND class IS NOT NULL
# AND age_at_incident IS NOT NULL
# AND age_at_incident <= 85
# AND race IS NOT NULL
# AND gender IS NOT NULL
# AND gender NOT LIKE '%%Unknown%%'
# AND sentence_type NOT LIKE '%%Terminated%%'
# AND sentence_type NOT LIKE '%%Release%%'
# AND NOT (sentence_type = 'Death' AND commitment_type != 'Death')
# AND NOT (sentence_type = 'Death' AND commitment_unit = 'Term')
# AND sentence_phase != 'Summary Charge Info'
# AND charge_disposition != 'Nolle On Remand'
# AND charge_disposition != 'Nolle Prosecution'
# AND charge_disposition != 'Death Suggested-Cause Abated'
# AND charge_disposition != 'FNG Reason Insanity'
# AND charge_disposition != 'BFW'
# AND charge_disposition != 'FNG'
# AND charge_disposition != 'Case Dismissed'
# AND charge_disposition != 'Charge Vacated'
# AND charge_disposition != 'Charge Reversed'
# AND charge_disposition != 'Superseded by Indictment'
# AND charge_disposition != 'SOLW'
# AND charge_disposition != 'Sexually Dangerous Person'
# AND charge_disposition != 'Superseded by Indictment'
# AND charge_disposition != 'FNPC'
# AND charge_disposition != 'Verdict-Not Guilty'
# AND charge_disposition != 'WOWI'
#
# ''', cnx)

# %%
# df.to_pickle('../Pickles/df.pkl')

# %%
df = pd.read_pickle('../Pickles/df.pkl')

# %%
df.columns
# Out:
# Index(['case_id', 'case_participant_id', 'charge_id', 'charge_version_id',
#        'primary_charge', 'offense_title', 'chapter', 'act', 'section', 'class',
#        'aoic', 'dispo_date', 'sentence_phase', 'sentence_date',
#        'sentence_judge', 'sentence_type', 'commitment_type', 'commitment_term',
#        'commitment_unit', 'charge_disposition', 'charge_disposition_reason',
#        'court_name', 'court_facility', 'case_length_dats', 'age_at_incident',
#        'gender', 'race', 'offense_type', 'incident_begin_date',
#        'incident_end_date', 'arrest_date', 'law_enforcement_agency', 'unit',
#        'incident_city', 'received_date', 'arraigment_date',
#        'current_sentence'],
#       dtype='object')

# %%
# checked value counts for individual years.
# data seems to be from 2014-2018 with incorrect values outside of those 5 years.
pd.Series(df['arrest_date']).dt.year.value_counts().head()
# Out:
# 2012.0    25454
# 2013.0    25407
# 2011.0    24480
# 2014.0    22932
# 2015.0    21353
# Name: arrest_date, dtype: int64

# %%
len(df)
# Out:
# 170973

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170973 entries, 0 to 170972
# Data columns (total 37 columns):
# case_id                      170973 non-null object
# case_participant_id          170973 non-null object
# charge_id                    170973 non-null object
# charge_version_id            170973 non-null object
# primary_charge               170973 non-null object
# offense_title                170973 non-null object
# chapter                      170973 non-null object
# act                          169726 non-null object
# section                      169726 non-null object
# class                        170973 non-null object
# aoic                         170969 non-null object
# dispo_date                   170973 non-null object
# sentence_phase               170973 non-null object
# sentence_date                170973 non-null object
# sentence_judge               170378 non-null object
# sentence_type                170973 non-null object
# commitment_type              170385 non-null object
# commitment_term              170381 non-null object
# commitment_unit              170381 non-null object
# charge_disposition           170973 non-null object
# charge_disposition_reason    12 non-null object
# court_name                   170860 non-null object
# court_facility               170323 non-null object
# case_length_dats             170973 non-null int64
# age_at_incident              170973 non-null int64
# gender                       170973 non-null object
# race                         170973 non-null object
# offense_type                 170973 non-null object
# incident_begin_date          170973 non-null datetime64[ns]
# incident_end_date            15844 non-null datetime64[ns]
# arrest_date                  168373 non-null datetime64[ns]
# law_enforcement_agency       170973 non-null object
# unit                         59144 non-null object
# incident_city                164498 non-null object
# received_date                170973 non-null datetime64[ns]
# arraigment_date              170973 non-null datetime64[ns]
# current_sentence             170973 non-null object
# dtypes: datetime64[ns](5), int64(2), object(30)
# memory usage: 48.3+ MB

# %%
# set sorting of dataframe so that all cases would be grouped together, keeping case participants separate,
# and keeping the primary charge at the top for each case participant.
df = deepcopy(df.sort_values(by = ['case_id', 'case_participant_id', 'sentence_phase', 'primary_charge',
                                   'current_sentence', 'charge_id', 'charge_version_id', 'case_length_dats'], ascending = False))

# %%
# removed duplicate rows within the dataframe.
duplicate_list = ['case_id', 'case_participant_id', 'charge_id', 'charge_version_id', 'sentence_phase']

df.drop_duplicates(subset = duplicate_list, keep = 'first', inplace = True)

# %%
df.head()
# Out:
#            case_id case_participant_id     charge_id charge_version_id  \
# 2120   97088524807        196998094338  375154247994      229717533075
# 4172   96622179616        194863086388  370310318969      115665167164
# 2928   93727898074        186460027426  881813691579      566165492444
# 32795  93727898074        186460027426  881812708514      566164862105
# 19971  93727898074        186460027426  881812462748      566164704520
#
#       primary_charge                             offense_title  \
# 2120           false            MURDER/STRONG PROB KILL/INJURE
# 4172            true  AGGRAVATED DUI/3RD+ (INACTIVE 12-2-1999)
# 2928            true                            ATTEMPT MURDER
# 32795          false                             HOME INVASION
# 19971          false         AGGRAVATED BATTERY WITH A FIREARM
#
#                    chapter   act       section class        aoic  \
# 2120                   720     5     9-1(A)(2)     M  0000735100
# 4172   625-5\11-501(D)(1)A  None          None     4  0000010632
# 2928                    38     -      8-4(9-1)     X     9999999
# 32795                  720     5   12-11(a)(1)     X     0995100
# 19971                  720     5  12-4.2(a)(1)     X     0940200
#
#                 dispo_date       sentence_phase        sentence_date  \
# 2120   2012-07-06 00:00:00  Original Sentencing  2012-07-06 00:00:00
# 4172   2013-08-23 00:00:00  Original Sentencing  2013-08-23 00:00:00
# 2928   2012-10-29 00:00:00  Original Sentencing  2012-10-25 00:00:00
# 32795  2012-10-29 00:00:00  Original Sentencing  2012-10-25 00:00:00
# 19971  2012-10-29 00:00:00  Original Sentencing  2012-10-25 00:00:00
#
#              sentence_judge sentence_type                     commitment_type  \
# 2120         James L Rhodes        Prison  Illinois Department of Corrections
# 4172   Timothy Joseph Joyce     Probation                           Probation
# 2928        Nicholas R Ford        Prison  Illinois Department of Corrections
# 32795       Nicholas R Ford        Prison  Illinois Department of Corrections
# 19971       Nicholas R Ford        Prison  Illinois Department of Corrections
#
#       commitment_term commitment_unit charge_disposition  \
# 2120               50         Year(s)     Finding Guilty
# 4172                2         Year(s)     Plea Of Guilty
# 2928               10         Year(s)     Plea Of Guilty
# 32795              10         Year(s)     Plea Of Guilty
# 19971              10         Year(s)     Plea Of Guilty
#
#       charge_disposition_reason            court_name      court_facility  \
# 2120                       None  District 6 - Markham  Markham Courthouse
# 4172                       None  District 1 - Chicago         26TH Street
# 2928                       None  District 1 - Chicago         26TH Street
# 32795                      None  District 1 - Chicago         26TH Street
# 19971                      None  District 1 - Chicago         26TH Street
#
#        case_length_dats  age_at_incident  gender                        race  \
# 2120               6064               22  Female                       Black
# 4172               6513               37    Male                       ASIAN
# 2928                 37               39    Male  White [Hispanic or Latino]
# 32795                37               39    Male  White [Hispanic or Latino]
# 19971                37               39    Male  White [Hispanic or Latino]
#
#                                    offense_type incident_begin_date  \
# 2120             MURDER/STRONG PROB KILL/INJURE          1995-10-22
# 4172   AGGRAVATED DUI/3RD+ (INACTIVE 12-2-1999)          1995-09-03
# 2928                             ATTEMPT MURDER          1994-09-15
# 32795                             HOME INVASION          1994-09-15
# 19971         AGGRAVATED BATTERY WITH A FIREARM          1994-09-15
#
#       incident_end_date arrest_date          law_enforcement_agency  unit  \
# 2120                NaT  1995-10-23  CHICAGO HTS. POLICE DEPARTMENT  None
# 4172                NaT  1995-10-03             CHICAGO POLICE DEPT  None
# 2928                NaT  2012-08-07                      CHICAGO PD  None
# 32795               NaT  2012-08-07                      CHICAGO PD  None
# 19971               NaT  2012-08-07                      CHICAGO PD  None
#
#       incident_city received_date arraigment_date current_sentence
# 2120           None    1995-10-23      1995-11-29             true
# 4172           None    1995-09-25      1995-10-24             true
# 2928        Chicago    1994-09-16      2012-09-18             true
# 32795       Chicago    1994-09-16      2012-09-18             true
# 19971       Chicago    1994-09-16      2012-09-18             true

# %%
# created a new dataframe to join on df so that we will have num_charges field in row with primary charge.
# num_charges will be 1 if the primary_charge was the only charge recorded.
aggregations = {
    'primary_charge': 'count',
    }

num_charges_df = deepcopy(df.groupby(['case_id', 'case_participant_id', 'sentence_phase']).agg(aggregations).reset_index().sort_values(by = 'primary_charge', ascending = False))
num_charges_df.rename({'primary_charge': 'num_charges', 'age_at_incident': 'crime_age'}, axis = 1, inplace = True)

# %%
num_charges_df.columns
# Out:
# Index(['case_id', 'case_participant_id', 'sentence_phase', 'num_charges'], dtype='object')

# %%
# removed duplicates so that for each case_participant_id with multiple charges, only the primary_charge was kept.
duplicate_list = ['case_id', 'case_participant_id', 'sentence_phase']

df.drop_duplicates(subset = duplicate_list, keep = 'first', inplace = True)

# %%
len(df)
# Out:
# 149528

# %%
# merged df with num_charges_df so that we have num_charges alongside primary_charge.
df = deepcopy(pd.merge(df, num_charges_df, on = ['case_id', 'case_participant_id', 'sentence_phase']))

# %%
df = deepcopy(df.sort_values(by = 'num_charges', ascending = False))

# %%
df.head()
# Out:
#             case_id case_participant_id     charge_id charge_version_id  \
# 1528    54534118758        267143062684  169237066686      292086903181
# 1351    64101350425        303689688939  224046616979      290747747868
# 81875  120341937685       1137495550496  910054686239      584497643049
# 1057    68505760820        317257157127  360176641023      284953434939
# 81416  120386410223       1138163714096  910440907831      584749148330
#
#       primary_charge                 offense_title            chapter   act  \
# 1528            true  MURDER/OTHER FORCIBLE FELONY                720     5
# 1351            true  OWN/BREED/TRAIN FIGHTING DOG      720-5\26-5(A)  None
# 81875           true           FIRST DEGREE MURDER                720     5
# 1057            true   THEFT/UNAUTHD CON/>10K<100K  720-5\16-1(A)(1)6  None
# 81416           true           FIRST DEGREE MURDER                720     5
#
#          section class        aoic           dispo_date       sentence_phase  \
# 1528   9-1(A)(3)     M  0000735200  2012-04-16 00:00:00  Original Sentencing
# 1351        None     4  0000012759  2011-11-09 00:00:00  Original Sentencing
# 81875  9-1(a)(1)     M     0735000  2016-04-28 00:00:00  Original Sentencing
# 1057        None     2  0001014600  2011-05-24 00:00:00  Original Sentencing
# 81416  9-1(a)(1)     M     0735000  2015-12-07 00:00:00  Original Sentencing
#
#              sentence_date      sentence_judge sentence_type  \
# 1528   2012-04-16 00:00:00     Luciano  Panici        Prison
# 1351   2011-12-14 00:00:00    Brian K Flaherty        Prison
# 81875  2016-08-29 00:00:00   Thaddeus L Wilson        Prison
# 1057   2011-05-24 00:00:00  Frank G Zelezinski        Prison
# 81416  2016-01-07 00:00:00   Thaddeus L Wilson          Jail
#
#                           commitment_type commitment_term commitment_unit  \
# 1528   Illinois Department of Corrections              30    Natural Life
# 1351   Illinois Department of Corrections               3         Year(s)
# 81875  Illinois Department of Corrections              75         Year(s)
# 1057   Illinois Department of Corrections              54          Months
# 81416  Illinois Department of Corrections              55         Year(s)
#
#       charge_disposition charge_disposition_reason            court_name  \
# 1528      Verdict Guilty                      None  District 6 - Markham
# 1351      Finding Guilty                      None  District 6 - Markham
# 81875     Finding Guilty                      None  District 1 - Chicago
# 1057      Plea Of Guilty                      None  District 6 - Markham
# 81416     Finding Guilty                      None  District 1 - Chicago
#
#            court_facility  case_length_dats  age_at_incident  gender  \
# 1528   Markham Courthouse              2776               33    Male
# 1351               PROMIS              1569               29    Male
# 81875         26TH Street              1061               34    Male
# 1057   Markham Courthouse               777               31  Female
# 81416         26TH Street               825               33    Male
#
#                              race                  offense_type  \
# 1528                        Black  MURDER/OTHER FORCIBLE FELONY
# 1351                        Black  OWN/BREED/TRAIN FIGHTING DOG
# 81875                       Black           FIRST DEGREE MURDER
# 1057                        Black   THEFT/UNAUTHD CON/>10K<100K
# 81416  White [Hispanic or Latino]           FIRST DEGREE MURDER
#
#       incident_begin_date incident_end_date arrest_date  \
# 1528           2004-07-06        2004-07-07  2004-07-20
# 1351           2007-07-13               NaT  2007-07-13
# 81875          2013-08-10               NaT  2013-08-14
# 1057           2009-01-14        2009-02-10  2009-02-24
# 81416          2013-08-16               NaT  2013-08-16
#
#             law_enforcement_agency                         unit incident_city  \
# 1528     ROBBINS POLICE DEPARTMENT                         None          None
# 1351           COOK CO SHERIFF OFF                         None          None
# 81875                   CHICAGO PD                         None       Chicago
# 1057   FLOSSMOOR POLICE DEPARTMENT                         None          None
# 81416                   CHICAGO PD  District 25 - Grand Central       Chicago
#
#       received_date arraigment_date current_sentence  num_charges
# 1528     2004-08-24      2004-09-09             true           99
# 1351     2007-07-14      2007-08-28             true           74
# 81875    2013-08-11      2013-10-03             true           59
# 1057     2009-02-24      2009-04-07             true           54
# 81416    2013-08-17      2013-10-04             true           42

# %%
df.columns
# Out:
# Index(['case_id', 'case_participant_id', 'charge_id', 'charge_version_id',
#        'primary_charge', 'offense_title', 'chapter', 'act', 'section', 'class',
#        'aoic', 'dispo_date', 'sentence_phase', 'sentence_date',
#        'sentence_judge', 'sentence_type', 'commitment_type', 'commitment_term',
#        'commitment_unit', 'charge_disposition', 'charge_disposition_reason',
#        'court_name', 'court_facility', 'case_length_dats', 'age_at_incident',
#        'gender', 'race', 'offense_type', 'incident_begin_date',
#        'incident_end_date', 'arrest_date', 'law_enforcement_agency', 'unit',
#        'incident_city', 'received_date', 'arraigment_date', 'current_sentence',
#        'num_charges'],
#       dtype='object')

# %%
# converted 'true'/'false' strings to booleans.
df.loc[df['primary_charge'] == 'true', 'primary_charge'] = True
df.loc[df['primary_charge'] == 'false', 'primary_charge'] = False
df.loc[df['current_sentence'] == 'true', 'current_sentence'] = True
df.loc[df['current_sentence'] == 'false', 'current_sentence'] = False

# fixed natural life commitment formatting for consistencies with other labels.
df.loc[df['commitment_type'] == 'Natural Life', 'commitment_term'] = 1
df.loc[df['commitment_type'] == 'Natural Life', 'commitment_unit'] = 'Natural Life'

# made all commitment terms a minimum of 1, since all rows contained sentencing time.
df.loc[df['commitment_term'] == '0', 'commitment_term'] = 1

# combined all plea labels into one 'Plead Guilty' vs 'Found Guilty' for binary classification.
df.loc[['Plea' in s for s in df['charge_disposition']], 'trial_outcome'] = 'Plead Guilty'
df.loc[df['trial_outcome'].isnull(), 'trial_outcome'] = 'Found Guilty'

# created new column for mental state based on if the charge disposition mentioned mental health.
df.loc[['Mental' in s for s in df['charge_disposition']], 'mental_state'] = 'Mentally Ill'
df.loc[df['sentence_type'] == 'Inpatient Mental Health Services', 'mental_state'] = 'Mentally Ill'
df.loc[df['mental_state'].isnull(), 'mental_state'] = 'Healthy'

# simplified class with new column class_adj, containing only M and X, since those are the two most severe classes.
df.loc[(df['class'] != 'M') & (df['class'] != 'X'), 'class_adj'] = 'Other'
df.loc[df['class'] == 'M', 'class_adj'] = 'M'
df.loc[df['class'] == 'X', 'class_adj'] = 'X'

# created new field incident_arraignment_window to remove rows
# where the arraignment was before the crime was committed, as this does not make sense logically.
df['incident_arraignment_window'] = df['arraigment_date'] - df['incident_begin_date']
df = deepcopy(df[df['incident_arraignment_window'].dt.days >= 0].reset_index())

# consolidated raace labels and removed American Indian as it had fewer that 100 rows.
df.loc[df['race'] == 'HISPANIC', 'race'] = 'Hispanic'
df.loc[df['race'] == 'White [Hispanic or Latino]', 'race'] = 'Biracial'
df.loc[df['race'] == 'White/Black [Hispanic or Latino]', 'race'] = 'Biracial'
df.loc[df['race'] == 'ASIAN', 'race'] = 'Asian'
df.loc[df['race'] == 'American Indian', 'race'] = 'Unknown'

# consolidated gener labels
df.loc[df['gender'] == 'Male name, no gender given', 'gender'] = 'Male'

# removed rows where commitment_type, commitment_term and commitment_unit were all not recorded.
df = deepcopy(df[(df['commitment_type'].isnull() == False) | (df['commitment_term'].isnull() == False) | (df['commitment_unit'].isnull() == False)].reset_index())

# removed all mentally ill defendants from the dataset,
# so that mental health would not be a confounding variable in my model.
df = deepcopy(df[df['mental_state'] == 'Healthy'])

# defining term length for cook county bootcamp
# numbers for one term obtained from bootcamp website
df.loc[df['commitment_unit'] == 'Term', 'commitment_term'] = 18
df.loc[df['commitment_unit'] == 'Term', 'commitment_unit'] = 'Weeks'

# removed rows where commitmnet_unit was in weight/money, as I am looking only at sentencing time.
df = deepcopy(df[(df['commitment_unit'] != 'Dollars') & (df['commitment_unit'] != 'Pounds') & (df['commitment_unit'] != 'Kilos') & (df['commitment_unit'].isnull() == False)])

# converted commitment unit to number of hours in one unit, making the assumption a life sentence is 100 years long.
df.loc[df['commitment_unit'] == 'Hours', 'commitment_unit'] = 1
df.loc[df['commitment_unit'] == 'Days', 'commitment_unit'] = 24
df.loc[df['commitment_unit'] == 'Weeks', 'commitment_unit'] = 168
df.loc[df['commitment_unit'] == 'Months', 'commitment_unit'] = 730
df.loc[df['commitment_unit'] == 'Year(s)', 'commitment_unit'] = 8760
df.loc[df['commitment_unit'] == 'Natural Life', 'commitment_unit'] = 876000

# removed strings from commitment_term
df['commitment_term'] = df['commitment_term'].astype(str)
df['commitment_term'] = ([s.split(' months')[0] for s in df['commitment_term']])
df['commitment_term'] = ([s.replace('`', '') for s in df['commitment_term']])
df.loc[df['commitment_term'] == 'two', 'commitment_term'] = 2
df['commitment_term'] = df['commitment_term'].astype(float)

# created new field hours_sentenced by multiplying commitment_term by commitment_unit.
# created new field sentence_years by dividing hours_sentenced by number of hours in a year.
df['hours_sentenced'] = deepcopy(df['commitment_term'] * df['commitment_unit'])
df['sentence_years'] = deepcopy(df['hours_sentenced'] / 8760)
# df = deepcopy(df[df['incident_arraignment_window'].dt.days >= 0].reset_index())

# standardized incident_arraignment_window as years_until_charged by dividing by number of days in a year.
df['incident_arraignment_window'] = ([s.split(' ')[0] for s in df['incident_arraignment_window'].astype(str)])
df['years_until_charged'] = df['incident_arraignment_window'].astype(int)/365

# combined all different types of probation sentences into one for consolidation.
df.loc[(['Probation' in s for s in df['sentence_type']]), 'sentence_type'] = 'Probation'

# standardized case_length_dats as case_years by dividing by number of days in a year.
df['case_years'] = df['case_length_dats']/365

# %%
df.rename({'primary_charge': 'highest_charge'}, axis = 1, inplace = True)

# %%
# dropped un-needed columns from the dataframe.
df.drop(['charge_version_id', 'chapter', 'act', 'section', 'aoic',
         'dispo_date', 'sentence_judge', 'commitment_type', 'offense_type',
         'charge_disposition_reason', 'incident_end_date', 'unit',
         'incident_city', 'charge_disposition', 'class',
         'incident_begin_date', 'sentence_date', 'court_facility',
         'arrest_date', 'arraigment_date', 'received_date',
         'commitment_term', 'commitment_unit', 'level_0',
         'index', 'court_name', 'law_enforcement_agency',
         'incident_arraignment_window', 'case_id', 'case_participant_id',
         'charge_id', 'case_length_dats', 'hours_sentenced', 'mental_state'], axis = 1, inplace = True)

# %%
# removed rows where defendatns had over 500 years sentencing time to avoid unreliable outliers.
df = deepcopy(df[df['sentence_years'] <= 500])

# %%
df.to_pickle('../Pickles/df_clean.pkl')

# %%
df = pd.read_pickle('../Pickles/df_clean.pkl')

# %%
len(df)
# Out:
# 148703

# %%
len(df[df['race'].isnull()])
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 148703 entries, 1 to 148791
# Data columns (total 14 columns):
# highest_charge         148703 non-null bool
# offense_title          148703 non-null object
# sentence_phase         148703 non-null object
# sentence_type          148703 non-null object
# age_at_incident        148703 non-null int64
# gender                 148703 non-null object
# race                   148703 non-null object
# current_sentence       148703 non-null bool
# num_charges            148703 non-null int64
# trial_outcome          148703 non-null object
# class_adj              148703 non-null object
# sentence_years         148703 non-null float64
# years_until_charged    148703 non-null float64
# case_years             148703 non-null float64
# dtypes: bool(2), float64(3), int64(2), object(7)
# memory usage: 15.0+ MB

# %%
df['sentence_type'].value_counts()
# Out:
# Prison                   79529
# Probation                60351
# Jail                      4317
# Cook County Boot Camp     1757
# Conditional Discharge     1627
# Supervision               1095
# Conversion                  25
# Death                        2
# Name: sentence_type, dtype: int64

# %%
len(df[df['gender'].isnull()])
# Out:
# 0

# %%
# all death sentences need to be for life
df[df['sentence_type'] == 'Death']
# Out:
#       highest_charge                       offense_title       sentence_phase  \
# 635             True  AGGRAVATED CRIMINAL SEXUAL ASSAULT  Original Sentencing
# 1738            True                 FIRST DEGREE MURDER  Original Sentencing
#
#      sentence_type  age_at_incident gender   race  current_sentence  \
# 635          Death               52   Male  Black              True
# 1738         Death               18   Male  Black              True
#
#       num_charges trial_outcome class_adj  sentence_years  \
# 635             6  Found Guilty         X           100.0
# 1738            3  Found Guilty         M           100.0
#
#       years_until_charged  case_years
# 635              0.150685    3.427397
# 1738             0.123288    4.389041

# %%
df['trial_outcome'].value_counts()
# Out:
# Plead Guilty    139144
# Found Guilty      9559
# Name: trial_outcome, dtype: int64
